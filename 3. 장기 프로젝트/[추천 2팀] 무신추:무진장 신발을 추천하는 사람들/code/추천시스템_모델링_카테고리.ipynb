# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_man = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/무신사 코디맵 크롤링한 데이터/all_man_pulsnaver.csv')
df_woman = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/무신사 코디맵 크롤링한 데이터/all_woman_pulsnaver.csv')

# %%
df_m_boatshoes = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/boatshoes_m.csv')
df_m_boots = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/boots_m.csv')
df_m_driving = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/driving_m.csv')
df_m_heel = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/heel_m.csv')
df_m_moca = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/moca_m.csv')
df_m_sandle = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/sandle_m.csv')
df_m_slipper = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/slipper_m.csv')
df_m_sneakers = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/sneakers_m.csv')
df_m_special = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/남성/special_m.csv')

# %%
df_w_boots = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/boots_w.csv')
df_w_flat = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/flat_w.csv')
df_w_heel = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/heel_w.csv')
df_w_sandle = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/sandle_w.csv')
df_w_sliper = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/sliper_w.csv')
df_w_sneakers = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/sneakers_w.csv')
df_w_special = pd.read_csv('/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/네이버쇼핑 클롤링한 데이터/여성/special_w.csv')

# %%
df_man_img = df_man[['title','prd_title','prd_img','category','category_naver','prd_title_naver']]
df_woman_img = df_woman[['title','prd_title','prd_img','category','category_naver','prd_title_naver']]

# %%
df_m_boatshoes_img = df_m_boatshoes[['product', 'category']]
df_m_boots_img = df_m_boots[['product', 'category']]
df_m_driving_img = df_m_driving[['product', 'category']]
df_m_heel_img = df_m_heel[['product', 'category']]
df_m_moca_img = df_m_moca[['product', 'category']]
df_m_sandle_img = df_m_sandle[['product', 'category']]
df_m_slipper_img = df_m_slipper[['product', 'category']]
df_m_sneakers_img = df_m_sneakers[['product', 'category']]
df_m_special_img = df_m_special[['product', 'category']]

# %%
df_w_boots_img = df_w_boots[['product', 'category']]
df_w_flat_img = df_w_flat[['product', 'category']]
df_w_heel_img = df_w_heel[['product', 'category']]
df_w_sandle_img = df_w_sandle[['product', 'category']]
df_w_sliper_img = df_w_sliper[['product', 'category']]
df_w_sneakers_img = df_w_sneakers[['product', 'category']]
df_w_special_img = df_w_special[['product', 'category']]

# %%
import os
import time
from urllib.request import urlretrieve

# %% [markdown]
# # category

# %% [markdown]
# 무신사에서 3번째 카테고리가 네이버 카테고리에 포함되는지 비교해서 있으면 해당 카테고리 이미지 파일과 비교해서 유사한 것 3개 추출하기

# %%
musinsa_cat_1 = df_man_img['category_naver']
musinsa_cat_2 = df_woman_img['category_naver']

# %%
drop_m = [242, 324, 326, 340, 352, 356, 397]
drop_w = [47, 164, 263, 303, 310, 312, 324, 335, 343, 354, 359, 362, 416, 540, 562, 568, 575, 639, 649]

# %%
df_man_img['musinsa_category'] = [[] for i in range(len(df_man_img))]

for i in range(len(df_man_img)):
  if i in drop_m:
    continue
  a = musinsa_cat_1[i].split("'")[5]
  df_man_img['musinsa_category'][i] = a
# Out:
# <ipython-input-11-27afcfd597fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man_img['musinsa_category'] = [[] for i in range(len(df_man_img))]
# <ipython-input-11-27afcfd597fb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man_img['musinsa_category'][i] = a

# %%
df_woman_img['musinsa_category'] = [[] for i in range(len(df_woman_img))]

for i in range(len(df_woman_img)):
  if i in drop_w:
    continue
  a = musinsa_cat_2[i].split("'")[5]
  df_woman_img['musinsa_category'][i] = a
# Out:
# <ipython-input-12-2feaf12deb7e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman_img['musinsa_category'] = [[] for i in range(len(df_woman_img))]
# <ipython-input-12-2feaf12deb7e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman_img['musinsa_category'][i] = a

# %%
d_m = df_man_img['musinsa_category']
d_w = df_woman_img['musinsa_category']

# %%
sneakers = ['스니커즈', '러닝화', '캔버스화', '하이탑', '워킹화', '보드화',
            '방수운동화', '쿠셔닝 운동화', '운동화', '운동화/스니커즈']
heel = ['구두', '로퍼', '블로퍼', '웰트화', '옥스포드화']
slipper = ['슬리퍼', '실내화']
moca = ['모카신/털신', '모카신', '털신']
boots = ['워커', '부츠', '레인부츠', '워커/부츠']
boatshoes = ['보트슈즈']
driving = ['드라이빙화']
sandle = ['샌들']
special = ['작업화/안전화', '컴포트화', '한복신발', '댄스화', '방한화', '기능화']

# %%
naver_cat_m = [[] for i in range(len(df_man_img))]

for i in range(len(df_man_img)):
  for j in range(len(sneakers)):
    if d_m[i] == sneakers[j]:
      naver_cat_m[i] = 'sneakers'
  for j in range(len(heel)):
    if d_m[i] == heel[j]:
      naver_cat_m[i] = 'heel'
  for j in range(len(slipper)):
    if d_m[i] == slipper[j]:
      naver_cat_m[i] = 'slipper'
  for j in range(len(moca)):
    if d_m[i] == moca[j]:
      naver_cat_m[i] = 'moca'
  for j in range(len(boots)):
    if d_m[i] == boots[j]:
      naver_cat_m[i] = 'boots'
  for j in range(len(boatshoes)):
    if d_m[i] == boatshoes[j]:
      naver_cat_m[i] = 'boatshoes'
  for j in range(len(driving)):
    if d_m[i] == driving[j]:
      naver_cat_m[i] = 'driving'
  for j in range(len(sandle)):
    if d_m[i] == sandle[j]:
      naver_cat_m[i] = 'sandle'
  for j in range(len(special)):
    if d_m[i] == special[j]:
      naver_cat_m[i] = 'special'

# %%
# naver_cat_m

# %%
m_drop = []
for i in range(len(naver_cat_m)):
  if len(naver_cat_m[i]) == 0:
    m_drop.append(i)

# %%
flat = ['단화', '로퍼', '슬립온', '옥스퍼드화', '모카신/털신']
sneakers = ['스니커즈', '러닝화', '워킹화', '캔버스화', '하이탑', '아쿠아슈즈', '보드화', '방수운동화', '쿠셔닝 운동화', '운동화', '운동화/스니커즈']
heel = ['구두', '슬링백힐', '펌프스', '하이힐', '스트랩힐', '토오픈힐', '가보시힐', '웨지힐', '통굽힐', '웨딩슈즈', '힐', '펌프스', '힐/펌프스']
sandle = ['샌들', '뮬/블로퍼', '스트랩샌들', '슬링백샌들', '웨지힐샌들', '아쿠아샌들', '젤리샌들', '글래디에이터샌들', '뮬', '뮬/샌들']
sliper = ['슬리퍼', '플랫 슬리퍼', '통굽 슬리퍼', '실내화', '슬리퍼/실내화']
special = ['기능화', '컴포트화', '다이어트화', '유니폼화', '작업화/안전화', '댄스화', '한복신발']
boots = ['부츠', '앵클/숏부츠', '미들부츠', '롱부츠', '워커', '부티', '부츠/워커']

# %%
naver_cat_w = [[] for i in range(len(df_woman_img))]

for i in range(len(df_woman_img)):
  for j in range(len(flat)):
    if d_w[i] == flat[j]:
      naver_cat_w[i] = 'flat'
  for j in range(len(sneakers)):
    if d_w[i] == sneakers[j]:
      naver_cat_w[i] = 'sneakers'
  for j in range(len(heel)):
    if d_w[i] == heel[j]:
      naver_cat_w[i] = 'heel'
  for j in range(len(sandle)):
    if d_w[i] == sandle[j]:
      naver_cat_w[i] = 'sandle'
  for j in range(len(sliper)):
    if d_w[i] == sliper[j]:
      naver_cat_w[i] = 'sliper'
  for j in range(len(special)):
    if d_w[i] == special[j]:
      naver_cat_w[i] = 'special'
  for j in range(len(boots)):
    if d_w[i] == boots[j]:
      naver_cat_w[i] = 'boots'

# %%
# naver_cat_w

# %%
w_drop = []
for i in range(len(naver_cat_w)):
  if len(naver_cat_w[i]) == 0:
    w_drop.append(i)

# %%
df_man_img['mus_na'] = naver_cat_m
df_woman_img['mus_na'] = naver_cat_w
# Out:
# <ipython-input-22-a74d7a6f9ff1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man_img['mus_na'] = naver_cat_m
# <ipython-input-22-a74d7a6f9ff1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman_img['mus_na'] = naver_cat_w

# %%
df_man_img
# Out:
#          title                                 prd_title  \
# 0      아메카지 감성               푸마 스커프 - 오트밀:블랙 / 384945-05
# 1    요즘 아메카지 룩                     German Military Panna
# 2    아메카지 멋 내기              ALC100 German_Sneakers Beige
# 3     뉴트럴 톤 코디       남성 6인치 프리미엄 부츠 - 라이트 베이지 누벅 / A2M19
# 4      아메카지 무드                      NICK 슬립온 W720042OA-M
# ..         ...                                       ...
# 422    트렌디한 조합             [Men] Caddie Golf G100701-001
# 423    누구나 어울려                    유로스 스니커즈 흰/빨(EUROS110)
# 424   골프 웨어 추천                        누에보 화이트 스파이크리스 골프화
# 425     완벽한 스윙  Mens Basic Spikeless Sneakers_Navy (Men)
# 426   데일리 필드 룩                  남성 엑슬 메탈 보아 (DN32MSSH71)
#
#                                                prd_img  \
# 0    //image.msscdn.net/images/goods_img/20220920/2...
# 1    //image.msscdn.net/images/goods_img/20210819/2...
# 2    //image.msscdn.net/images/goods_img/20210924/2...
# ...

# %% [markdown]
# # try

# %%
# cat1 = df_m_boatshoes['category']
# cat2 = df_m_boots['category']
# cat3 = df_m_driving['category']
# cat4 = df_m_heel['category']
# cat5 = df_m_moca['category']
# cat6 = df_m_sandle['category']
# cat7 = df_m_slipper['category']
# cat8 = df_m_sneakers['category']
# cat9 = df_m_special['category']

# %%
# cat0 = pd.concat([cat1, cat2, cat3, cat4, cat5, cat6, cat7, cat8, cat9], ignore_index = True)

# %%
# df_m_boatshoes_img['type'] = ['boatshoes' for i in range(len(df_m_boatshoes_img))]
# df_m_boots_img['type'] = ['boots' for i in range(len(df_m_boots_img))]
# df_m_driving_img['type'] = ['driving' for i in range(len(df_m_driving_img))]
# df_m_heel_img['type'] = ['heel' for i in range(len(df_m_heel_img))]
# df_m_moca_img['type'] = ['moca' for i in range(len(df_m_moca_img))]
# df_m_sandle_img['type'] = ['sandle' for i in range(len(df_m_sandle_img))]
# df_m_slipper_img['type'] = ['slipper' for i in range(len(df_m_slipper_img))]
# df_m_sneakers_img['type'] = ['sneakers' for i in range(len(df_m_sneakers_img))]
# df_m_special_img['type'] = ['special' for i in range(len(df_m_special_img))]

# %%
# type1 = df_m_boatshoes_img['type']
# type2 = df_m_boots_img['type']
# type3 = df_m_driving_img['type']
# type4 = df_m_heel_img['type']
# type5 = df_m_moca_img['type']
# type6 = df_m_sandle_img['type']
# type7 = df_m_slipper_img['type']
# type8 = df_m_sneakers_img['type']
# type9 = df_m_special_img['type']

# %%
# type0 = pd.concat([type1, type2, type3, type4, type5, type6, type7, type8, type9], ignore_index=True)

# %%
# cat_type = pd.concat([type0, cat0], axis = 1)

# %%
# naver_cat = [[] for i in range(len(df_man_img))]

# for i in range(len(df_man_img)):
#   for j in range(len(cat_type['category'])):
#     if d[i] in cat_type['category'][j]:
#       naver_cat[i] = cat_type['type'][j]

# %% [markdown]
# # 이미지 비교

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from pathlib import Path
from PIL import Image

# %%
class FeatureExtractor:
  def __init__(self):
        # Use VGG-16 as the architecture and ImageNet for the weight
        base_model = VGG16(weights='imagenet')
        # Customize the model to return features from fully-connected layer
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

  def extract(self, img):
        # Resize the image
        img = img.resize((224, 224))
        # Convert the image color space
        img = img.convert('RGB')
        # Reformat the image
        x = img
        x = np.expand_dims(x, axis=0) #차원추가
        x = preprocess_input(x) #모델에 필요한 형식에 이미지를 적절하게 맞추기위한 것
        # Extract Features
        feature = self.model.predict(x)[0]
        return feature / np.linalg.norm(feature)

# %%
images_m = [0 for i in range(len(df_man_img))]
features_m_vgg = [0 for i in range(len(df_man_img))]

man_drop = [39,55,244,245,246,285,307,309,310,311,312,314,315,316,317,318,319,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,340,341,342,343,344,345,346,347,348,349,350,351,353,354,355,356,357,358,359,360,362,363,364,365,366,414,418,421]
fe = FeatureExtractor()

for i in range(len(df_man_img)):
  if i in man_drop:
    continue
  img = Image.open(f"/content/drive/MyDrive/추천시스템/남성/man_{i}.jpg")
  fea = fe.extract(img)
  features_m_vgg[i] = fea
  images_m[i] = img

# %%
images_w = [0 for i in range(len(df_woman_img))]
features_w_vgg = [0 for i in range(len(df_woman_img))]

woman_drop = [47,77,134,139,148,149,157,171,220,273,313,314,315,319,321,329,342,352,353,356,357,397,404,413,415,424,427,447,461,477,479,504,510,513,527,529,530,537,541,542,544,545,547,548,549,550,551,553,554,555,557,558,559,560,561,563,565,566,569,570,573,574,575,576,578,579,582,583,584,585,587,588,589,590,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,609,610,611,612,613,614,615,616,617,618,620,621,622,623,624,625,626,628,629,631,632,637,638,639,644,645,647,648,649,651,652,653,654,658,659]
fe = FeatureExtractor()

for i in range(len(df_woman_img)):
  if i in woman_drop:
    continue
  img = Image.open(f"/content/drive/MyDrive/추천시스템/이미지/무신사/여성/woman_{i}.jpg")
  fea = fe.extract(img)
  features_w_vgg[i] = fea
  images_w[i] = img

# %%
img_m_boatshoes = [0 for i in range(len(df_m_boatshoes_img))]
features_m_boatshoes = [0 for i in range(len(df_m_boatshoes_img))]

for i in range(len(df_m_boatshoes_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_boatshoes/m_boatshoes{i}.jpg")
  fea = fe.extract(img)
  features_m_boatshoes[i] = fea
  img_m_boatshoes[i] = img

# %%
img_m_boots = [0 for i in range(len(df_m_boots_img))]
features_m_boots = [0 for i in range(len(df_m_boots_img))]

for i in range(len(df_m_boots_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_boots/m_boots{i}.jpg")
  fea = fe.extract(img)
  features_m_boots[i] = fea
  img_m_boots[i] = img

# %%
img_m_driving = [0 for i in range(len(df_m_driving_img))]
features_m_driving = [0 for i in range(len(df_m_driving_img))]

for i in range(len(df_m_driving_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_driving/m_driving{i}.jpg")
  fea = fe.extract(img)
  features_m_driving[i] = fea
  img_m_driving[i] = img

# %%
img_m_heel = [0 for i in range(len(df_m_heel_img))]
features_m_heel = [0 for i in range(len(df_m_heel_img))]

for i in range(len(df_m_heel_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_heel/m_heel{i}.jpg")
  fea = fe.extract(img)
  features_m_heel[i] = fea
  img_m_heel[i] = img

# %%
img_m_moca = [0 for i in range(len(df_m_moca_img))]
features_m_moca = [0 for i in range(len(df_m_moca_img))]

for i in range(len(df_m_moca_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_moca/m_moca{i}.jpg")
  fea = fe.extract(img)
  features_m_moca[i] = fea
  img_m_moca[i] = img

# %%
img_m_sandle = [0 for i in range(len(df_m_sandle_img))]
features_m_sandle = [0 for i in range(len(df_m_sandle_img))]

for i in range(len(df_m_sandle_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_sandle/m_sandle{i}.jpg")
  fea = fe.extract(img)
  features_m_sandle[i] = fea
  img_m_sandle[i] = img

# %%
img_m_slipper = [0 for i in range(len(df_m_slipper_img))]
features_m_slipper = [0 for i in range(len(df_m_slipper_img))]

for i in range(len(df_m_slipper_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_slipper/m_slipper{i}.jpg")
  fea = fe.extract(img)
  features_m_slipper[i] = fea
  img_m_slipper[i] = img

# %%
img_m_sneakers = [0 for i in range(len(df_m_sneakers_img))]
features_m_sneakers = [0 for i in range(len(df_m_sneakers_img))]

for i in range(len(df_m_sneakers_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_sneakers/m_sneakers{i}.jpg")
  fea = fe.extract(img)
  features_m_sneakers[i] = fea
  img_m_sneakers[i] = img

# %%
img_m_special = [0 for i in range(len(df_m_special_img))]
features_m_special = [0 for i in range(len(df_m_special_img))]

for i in range(len(df_m_special_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/m_special/m_special{i}.jpg")
  fea = fe.extract(img)
  features_m_special[i] = fea
  img_m_special[i] = img

# %%
img_w_boots = [0 for i in range(len(df_w_boots_img))]
features_w_boots = [0 for i in range(len(df_w_boots_img))]

for i in range(len(df_w_boots_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_boots/w_boots{i}.jpg")
  fea = fe.extract(img)
  features_w_boots[i] = fea
  img_w_boots[i] = img

# %%
img_w_flat = [0 for i in range(len(df_w_flat_img))]
features_w_flat = [0 for i in range(len(df_w_flat_img))]

for i in range(len(df_w_flat_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_flat/w_flat{i}.jpg")
  fea = fe.extract(img)
  features_w_flat[i] = fea
  img_w_flat[i] = img

# %%
img_w_heel = [0 for i in range(len(df_w_heel_img))]
features_w_heel = [0 for i in range(len(df_w_heel_img))]

for i in range(len(df_w_heel_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_heel/w_heel{i}.jpg")
  fea = fe.extract(img)
  features_w_heel[i] = fea
  img_w_heel[i] = img

# %%
img_w_sandle = [0 for i in range(len(df_w_sandle_img))]
features_w_sandle = [0 for i in range(len(df_w_sandle_img))]

for i in range(len(df_w_sandle_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_sandle/w_sandle{i}.jpg")
  fea = fe.extract(img)
  features_w_sandle[i] = fea
  img_w_sandle[i] = img

# %%
img_w_sliper = [0 for i in range(len(df_w_sliper_img))]
features_w_sliper = [0 for i in range(len(df_w_sliper_img))]

for i in range(len(df_w_sliper_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_sliper/w_sliper{i}.jpg")
  fea = fe.extract(img)
  features_w_sliper[i] = fea
  img_w_sliper[i] = img

# %%
img_w_sneakers = [0 for i in range(len(df_w_sneakers_img))]
features_w_sneakers = [0 for i in range(len(df_w_sneakers_img))]

for i in range(len(df_w_sneakers_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_sneakers/w_sneakers{i}.jpg")
  fea = fe.extract(img)
  features_w_sneakers[i] = fea
  img_w_sneakers[i] = img

# %%
img_w_special = [0 for i in range(len(df_w_special_img))]
features_w_special = [0 for i in range(len(df_w_special_img))]

for i in range(len(df_w_special_img)):
  img = Image.open(f"/content/drive/MyDrive/추천시스템/w_special/w_special{i}.jpg")
  fea = fe.extract(img)
  features_w_special[i] = fea
  img_w_special[i] = img

# %%
df_woman_img['feature_vgg'] = features_w_vgg
df_man_img['feature_vgg'] = features_m_vgg
# Out:
# <ipython-input-54-8beb9efb23a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman_img['feature_vgg'] = features_w_vgg
# <ipython-input-54-8beb9efb23a7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man_img['feature_vgg'] = features_m_vgg

# %%
df_m_boatshoes_img['feature_vgg'] = features_m_boatshoes
df_m_boots_img['feature_vgg'] = features_m_boots
df_m_driving_img['feature_vgg'] = features_m_driving
df_m_heel_img['feature_vgg'] = features_m_heel
df_m_moca_img['feature_vgg'] = features_m_moca
df_m_sandle_img['feature_vgg'] = features_m_sandle
df_m_slipper_img['feature_vgg'] = features_m_slipper
df_m_sneakers_img['feature_vgg'] = features_m_sneakers
df_m_special_img['feature_vgg'] = features_m_special

# %%
df_w_boots_img['feature_vgg'] = features_w_boots
df_w_flat_img['feature_vgg'] = features_w_flat
df_w_heel_img['feature_vgg'] = features_w_heel
df_w_sandle_img['feature_vgg'] = features_w_sandle
df_w_sliper_img['feature_vgg'] = features_w_sliper
df_w_sneakers_img['feature_vgg'] = features_w_sneakers
df_w_special_img['feature_vgg'] = features_w_special

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

def cos(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torch.autograd import Variable
from PIL import Image

# Load the pretrained model
model = models.resnet18(pretrained=True)

# Use the model object to select the desired layer
layer = model._modules.get('avgpool')

# Set model to evaluation mode
model.eval()

# Image transforms
scaler = transforms.Resize((224, 224))
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
to_tensor = transforms.ToTensor()

def get_vector(image_name):
    # 1. Load the image with Pillow library
    img = Image.open(image_name)
    img = img.convert('RGB')
    # 2. Create a PyTorch Variable with the transformed image
    t_img = Variable(normalize(to_tensor(scaler(img))).unsqueeze(0))
    # 3. Create a vector of zeros that will hold our feature vector
    #    The 'avgpool' layer has an output size of 512
    my_embedding = torch.zeros([1, 512, 1, 512])
    # 4. Define a function that will copy the output of a layer
    def copy_data(m, i, o):
        my_embedding.copy_(o.data)
    # 5. Attach that function to our selected layer
    h = layer.register_forward_hook(copy_data)
    # 6. Run the model on our transformed image
    model(t_img)
    # 7. Detach our copy function from the layer
    h.remove()
    # 8. Return the feature vector
    return my_embedding
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
def cos_pytorch(A, B):
  cos= nn.CosineSimilarity(dim=1, eps=1e-6)
  cos_sim = cos(A, B)
  return cos_sim.numpy()[0][0][0]

# %%
features_m_resnet = []
for i in range(len(df_man_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/남성/man_{i}.jpg")
  features_m_resnet.append(fea)

# %%
features_w_resnet = []
for i in range(len(df_woman_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/이미지/무신사/여성/woman_{i}.jpg")
  features_w_resnet.append(fea)

# %%
features_m_boatshoes_resnet = []
for i in range(len(df_m_boatshoes_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_boatshoes/m_boatshoes{i}.jpg")
  features_m_boatshoes_resnet.append(fea)

# %%
features_m_boots_resnet = []
for i in range(len(df_m_boots_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_boots/m_boots{i}.jpg")
  features_m_boots_resnet.append(fea)

# %%
features_m_driving_resnet = []
for i in range(len(df_m_driving_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_driving/m_driving{i}.jpg")
  features_m_driving_resnet.append(fea)

# %%
features_m_heel_resnet = []
for i in range(len(df_m_heel_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_heel/m_heel{i}.jpg")
  features_m_heel_resnet.append(fea)

# %%
features_m_moca_resnet = []
for i in range(len(df_m_moca_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_moca/m_moca{i}.jpg")
  features_m_moca_resnet.append(fea)

# %%
features_m_sandle_resnet = []
for i in range(len(df_m_sandle_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_sandle/m_sandle{i}.jpg")
  features_m_sandle_resnet.append(fea)

# %%
features_m_slipper_resnet = []
for i in range(len(df_m_slipper_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_slipper/m_slipper{i}.jpg")
  features_m_slipper_resnet.append(fea)

# %%
features_m_sneakers_resnet = []
for i in range(len(df_m_sneakers_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_sneakers/m_sneakers{i}.jpg")
  features_m_sneakers_resnet.append(fea)

# %%
features_m_special_resnet = []
for i in range(len(df_m_special_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/m_special/m_special{i}.jpg")
  features_m_special_resnet.append(fea)

# %%
features_w_boots_resnet = []
for i in range(len(df_w_boots_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_boots/w_boots{i}.jpg")
  features_w_boots_resnet.append(fea)

# %%
features_w_flat_resnet = []
for i in range(len(df_w_flat_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_flat/w_flat{i}.jpg")
  features_w_flat_resnet.append(fea)

# %%
features_w_heel_resnet = []
for i in range(len(df_w_heel_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_heel/w_heel{i}.jpg")
  features_w_heel_resnet.append(fea)

# %%
features_w_sandle_resnet = []
for i in range(len(df_w_sandle_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_sandle/w_sandle{i}.jpg")
  features_w_sandle_resnet.append(fea)

# %%
features_w_sliper_resnet = []
for i in range(len(df_w_sliper_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_sliper/w_sliper{i}.jpg")
  features_w_sliper_resnet.append(fea)

# %%
features_w_sneakers_resnet = []
for i in range(len(df_w_sneakers_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_sneakers/w_sneakers{i}.jpg")
  features_w_sneakers_resnet.append(fea)

# %%
features_w_special_resnet = []
for i in range(len(df_w_special_img)):
  fea = get_vector(f"/content/drive/MyDrive/추천시스템/w_special/w_special{i}.jpg")
  features_w_special_resnet.append(fea)

# %%
df_man_img['feature_resnet'] = features_m_resnet
# Out:
# <ipython-input-81-9bff6326608c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man_img['feature_resnet'] = features_m_resnet

# %%
df_woman_img['feature_resnet'] = features_w_resnet
# Out:
# <ipython-input-82-47e409900367>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman_img['feature_resnet'] = features_w_resnet

# %%
df_m_boatshoes_img['feature_resnet'] = features_m_boatshoes_resnet
df_m_boots_img['feature_resnet'] = features_m_boots_resnet
df_m_driving_img['feature_resnet'] = features_m_driving_resnet
df_m_heel_img['feature_resnet'] = features_m_heel_resnet
df_m_moca_img['feature_resnet'] = features_m_moca_resnet
df_m_sandle_img['feature_resnet'] = features_m_sandle_resnet
df_m_slipper_img['feature_resnet'] = features_m_slipper_resnet
df_m_sneakers_img['feature_resnet'] = features_m_sneakers_resnet
df_m_special_img['feature_resnet'] = features_m_special_resnet
# Out:
# <ipython-input-83-9d9ad7a624fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m_boatshoes_img['feature_resnet'] = features_m_boatshoes_resnet
# <ipython-input-83-9d9ad7a624fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m_boots_img['feature_resnet'] = features_m_boots_resnet
# <ipython-input-83-9d9ad7a624fa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_w_boots_img['feature_resnet'] = features_w_boots_resnet
df_w_flat_img['feature_resnet'] = features_w_flat_resnet
df_w_heel_img['feature_resnet'] = features_w_heel_resnet
df_w_sandle_img['feature_resnet'] = features_w_sandle_resnet
df_w_sliper_img['feature_resnet'] = features_w_sliper_resnet
df_w_sneakers_img['feature_resnet'] = features_w_sneakers_resnet
df_w_special_img['feature_resnet'] = features_w_special_resnet
# Out:
# <ipython-input-84-a23dc4d5f90c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_boots_img['feature_resnet'] = features_w_boots_resnet

# %% [markdown]
# # 유클리디안 거리 기반 추천

# %%
images_m_resize = [i.resize((224, 224)).convert('RGB') for i in images_m]

# %%
images_m_array = [np.array(i) for i in images_m_resize]

# %%
dist = []
for i in range(len(images_m_array)):
  dis= np.linalg.norm(images_m_array[0] - images_m_array[i]) #0번째 사진에 대한 추천
  dist.append((dis,i))

# %%
c = sorted(dist)[:9] # 상위 9개만 선택

# %%
print(c) #거리와 유사 아이템 인덱스

# %%
index = [c[i][1] for i in range(len(c))]

# %%
from matplotlib import pyplot as plt

plt.figure(figsize = (10,5))

plt.subplot(2,5,1)
plt.imshow(images_m[0])
plt.axis('off')

for i in range(9):
  plt.subplot(2,5,i+2)
  plt.imshow(images_m[index[i]])
  plt.axis('off')

# %%
images_w_resize = [i.resize((224, 224)).convert('RGB') for i in images_w]

# %%
images_w_array = [np.array(i) for i in images_w_resize]

# %%
dist = []
for i in range(len(images_w_array)):
  dis= np.linalg.norm(images_w_array[0] - images_w_array[i]) #0번째 사진에 대한 추천
  dist.append((dis,i))

# %%
c = sorted(dist)[:9] # 상위 9개만 선택

# %%
print(c) #거리와 유사 아이템 인덱스

# %%
index = [c[i][1] for i in range(len(c))]

# %%
#추천 결과
from matplotlib import pyplot as plt

plt.figure(figsize = (10,5))

plt.subplot(2,5,1)
plt.imshow(images_w[0])
plt.axis('off')

for i in range(9):
  plt.subplot(2,5,i+2)
  plt.imshow(images_w[index[i]])
  plt.axis('off')

# %% [markdown]
# # Resnet18로 추출한 feature vector 간 cosine similarity 기반 추천

# %% [markdown]
# 남성 boatshoes

# %%
df_man['category_to_category'] = [[] for i in range(len(df_man))]
man_mus_na = df_man_img['mus_na']

# %%
for i in range(len(df_man_img['feature_resnet'])):
  if i in man_drop:
    continue
  
  if i in m_drop:
    continue

  cos_dist1 = []
  if man_mus_na[i] == 'boatshoes':
    for j in range(len(df_m_boatshoes_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_boatshoes_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_boatshoes_' + str(a[0][1]) + '.jpg',
                                 'man_boatshoes_' + str(a[1][1]) + '.jpg',
                                 'man_boatshoes_' + str(a[2][1]) + '.jpg',
                                 'man_boatshoes_' + str(a[3][1]) + '.jpg',
                                 'man_boatshoes_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'boots':
    for j in range(len(df_m_boots_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_boots_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_boots_' + str(a[0][1]) + '.jpg',
                                 'man_boots_' + str(a[1][1]) + '.jpg',
                                 'man_boots_' + str(a[2][1]) + '.jpg',
                                 'man_boots_' + str(a[3][1]) + '.jpg',
                                 'man_boots_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'driving':
    for j in range(len(df_m_driving_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_driving_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_driving_' + str(a[0][1]) + '.jpg',
                                 'man_driving_' + str(a[1][1]) + '.jpg',
                                 'man_driving_' + str(a[2][1]) + '.jpg',
                                 'man_driving_' + str(a[3][1]) + '.jpg',
                                 'man_driving_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'heel':
    for j in range(len(df_m_heel_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_heel_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_heel_' + str(a[0][1]) + '.jpg',
                                 'man_heel_' + str(a[1][1]) + '.jpg',
                                 'man_heel_' + str(a[2][1]) + '.jpg',
                                 'man_heel_' + str(a[3][1]) + '.jpg',
                                 'man_heel_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'moca':
    for j in range(len(df_m_moca_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_moca_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_moca_' + str(a[0][1]) + '.jpg',
                                 'man_moca_' + str(a[1][1]) + '.jpg',
                                 'man_moca_' + str(a[2][1]) + '.jpg',
                                 'man_moca_' + str(a[3][1]) + '.jpg',
                                 'man_moca_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'sandle':
    for j in range(len(df_m_sandle_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_sandle_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_sandle_' + str(a[0][1]) + '.jpg',
                                 'man_sandle_' + str(a[1][1]) + '.jpg',
                                 'man_sandle_' + str(a[2][1]) + '.jpg',
                                 'man_sandle_' + str(a[3][1]) + '.jpg',
                                 'man_sandle_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'slipper':
    for j in range(len(df_m_slipper_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_slipper_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_slipper_' + str(a[0][1]) + '.jpg',
                                 'man_slipper_' + str(a[1][1]) + '.jpg',
                                 'man_slipper_' + str(a[2][1]) + '.jpg',
                                 'man_slipper_' + str(a[3][1]) + '.jpg',
                                 'man_slipper_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'sneakers':
    for j in range(len(df_m_sneakers_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_sneakers_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_sneakers_' + str(a[0][1]) + '.jpg',
                                 'man_sneakers_' + str(a[1][1]) + '.jpg',
                                 'man_sneakers_' + str(a[2][1]) + '.jpg',
                                 'man_sneakers_' + str(a[3][1]) + '.jpg',
                                 'man_sneakers_' + str(a[4][1]) + '.jpg',]
  if man_mus_na[i] == 'special':
    for j in range(len(df_m_special_img['feature_resnet'])):
      dist= cos_pytorch(df_man_img['feature_resnet'][i],df_m_special_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_man['category_to_category'][i] = ['man_special_' + str(a[0][1]) + '.jpg',
                                 'man_special_' + str(a[1][1]) + '.jpg',
                                 'man_special_' + str(a[2][1]) + '.jpg',
                                 'man_special_' + str(a[3][1]) + '.jpg',
                                 'man_special_' + str(a[4][1]) + '.jpg',]

  #   a = sorted(cos_dist1, reverse=True)[1:6]
  
  # df_man['category_to_category'][i] = ['man_boatshoes_' + str(a[0][1]) + '.jpg',
  #                                'man_boatshoes_' + str(a[1][1]) + '.jpg',
  #                                'man_boatshoes_' + str(a[2][1]) + '.jpg',
  #                                'man_boatshoes_' + str(a[3][1]) + '.jpg',
  #                                'man_boatshoes_' + str(a[4][1]) + '.jpg',]

# %%
df_man['category_to_category']

# %%
df_woman['category_to_category'] = [[] for i in range(len(df_woman))]
woman_mus_na = df_woman_img['mus_na']

# %%
for i in range(len(df_woman_img['feature_resnet'])):
  if i in woman_drop:
    continue
  
  if i in w_drop:
    continue

  cos_dist1 = []
  if woman_mus_na[i] == 'boots':
    for j in range(len(df_w_boots_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_boots_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_boots_' + str(a[0][1]) + '.jpg',
                                 'woman_boots_' + str(a[1][1]) + '.jpg',
                                 'woman_boots_' + str(a[2][1]) + '.jpg',
                                 'woman_boots_' + str(a[3][1]) + '.jpg',
                                 'woman_boots_' + str(a[4][1]) + '.jpg',]
  if woman_mus_na[i] == 'flat':
    for j in range(len(df_w_flat_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_flat_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_flat_' + str(a[0][1]) + '.jpg',
                                 'woman_flat_' + str(a[1][1]) + '.jpg',
                                 'woman_flat_' + str(a[2][1]) + '.jpg',
                                 'woman_flat_' + str(a[3][1]) + '.jpg',
                                 'woman_flat_' + str(a[4][1]) + '.jpg',]
  if woman_mus_na[i] == 'heel':
    for j in range(len(df_w_heel_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_heel_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_heel_' + str(a[0][1]) + '.jpg',
                                 'woman_heel_' + str(a[1][1]) + '.jpg',
                                 'woman_heel_' + str(a[2][1]) + '.jpg',
                                 'woman_heel_' + str(a[3][1]) + '.jpg',
                                 'woman_heel_' + str(a[4][1]) + '.jpg',]
  if woman_mus_na[i] == 'sandle':
    for j in range(len(df_w_sandle_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_sandle_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_sandle_' + str(a[0][1]) + '.jpg',
                                 'woman_sandle_' + str(a[1][1]) + '.jpg',
                                 'woman_sandle_' + str(a[2][1]) + '.jpg',
                                 'woman_sandle_' + str(a[3][1]) + '.jpg',
                                 'woman_sandle_' + str(a[4][1]) + '.jpg',]  
  if woman_mus_na[i] == 'sliper':
    for j in range(len(df_w_sliper_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_sliper_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_sliper_' + str(a[0][1]) + '.jpg',
                                 'woman_sliper_' + str(a[1][1]) + '.jpg',
                                 'woman_slipper_' + str(a[2][1]) + '.jpg',
                                 'woman_sliper_' + str(a[3][1]) + '.jpg',
                                 'woman_sliper_' + str(a[4][1]) + '.jpg',]
  if woman_mus_na[i] == 'sneakers':
    for j in range(len(df_w_sneakers_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_sneakers_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_sneakers_' + str(a[0][1]) + '.jpg',
                                 'woman_sneakers_' + str(a[1][1]) + '.jpg',
                                 'woman_sneakers_' + str(a[2][1]) + '.jpg',
                                 'woman_sneakers_' + str(a[3][1]) + '.jpg',
                                 'woman_sneakers_' + str(a[4][1]) + '.jpg',]    
  if woman_mus_na[i] == 'special':
    for j in range(len(df_w_special_img['feature_resnet'])):
      dist= cos_pytorch(df_woman_img['feature_resnet'][i],df_w_special_img['feature_resnet'][j])
      cos_dist1.append((dist,j))
    a = sorted(cos_dist1, reverse=True)[1:6]
    df_woman['category_to_category'][i] = ['woman_special_' + str(a[0][1]) + '.jpg',
                                 'woman_special_' + str(a[1][1]) + '.jpg',
                                 'woman_special_' + str(a[2][1]) + '.jpg',
                                 'woman_special_' + str(a[3][1]) + '.jpg',
                                 'woman_special_' + str(a[4][1]) + '.jpg',]
# Out:
# <ipython-input-91-a338296fb1a6>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman['category_to_category'][i] = ['woman_boots_' + str(a[0][1]) + '.jpg',
# <ipython-input-91-a338296fb1a6>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman['category_to_category'][i] = ['woman_sneakers_' + str(a[0][1]) + '.jpg',
# <ipython-input-91-a338296fb1a6>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_woman['category_to_category']
# Out:
# 0      [woman_boots_11.jpg, woman_boots_24.jpg, woman...
# 1      [woman_sneakers_41.jpg, woman_sneakers_44.jpg,...
# 2      [woman_sliper_29.jpg, woman_sliper_54.jpg, wom...
# 3      [woman_flat_3.jpg, woman_flat_33.jpg, woman_fl...
# 4      [woman_sliper_29.jpg, woman_sliper_51.jpg, wom...
#                              ...
# 655                                                   []
# 656    [woman_sandle_9.jpg, woman_sandle_17.jpg, woma...
# 657                                                   []
# 658                                                   []
# 659                                                   []
# Name: category_to_category, Length: 660, dtype: object

# %% [markdown]
# # csv 저장

# %%
df_man.to_csv("/content/drive/MyDrive/추천시스템/all_man_pulsnaver_pluscattocat.csv",index=False)

# %%
df_woman.to_csv("/content/drive/MyDrive/추천시스템/all_woman_pulsnaver_pluscattocat.csv",index=False)

# %% [markdown]
# 기존 데이터랑 concat하기

# %%
man1 = pd.read_csv('/content/drive/MyDrive/추천시스템/all_man_pulsnaver_pluscodishoes.csv',index_col=0)
woman1 = pd.read_csv('/content/drive/MyDrive/추천시스템/all_woman_pulsnaver_pluscodishoes.csv', index_col = 0)

# %%
man2 = pd.read_csv('/content/drive/MyDrive/추천시스템/all_man_pulsnaver_pluscattocat.csv',index_col=0)
woman2 = pd.read_csv('/content/drive/MyDrive/추천시스템/all_woman_pulsnaver_pluscattocat.csv', index_col = 0)

# %%
woman1 = woman1.reset_index()
woman2 = woman2.reset_index()
man = pd.concat([man1, man2['category_to_category']], axis=1)
woman = pd.concat([woman1, woman2['category_to_category']], axis=1)

# %%
man.to_csv("/content/drive/MyDrive/추천시스템/all_man_pulsnaver_all.csv", index=False)
woman.to_csv("/content/drive/MyDrive/추천시스템/all_woman_pulsnaver_alls.csv", index=False)

# %%
man.to_csv("/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/무신사 코디맵 크롤링한 데이터/all_man_pulsnaver_all.csv", index=False)
woman.to_csv("/content/drive/Shareddrives/2022-2 KUBIG 추천시스템/2팀/새로운시작/무신사 코디맵 크롤링한 데이터/all_woman_pulsnaver_all.csv", index=False)
